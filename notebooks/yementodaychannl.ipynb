# %% [markdown]
# In this notebook, we play around with using Capyldi (Capaldi?) to do bulk runs on the whereistheboom.csv dump.

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
import numpy.random as npr
from tqdm import tqdm
import requests
import sys

sys.path.append('../../../capyldi')
from capyldi import capyldi

# %matplotlib inline

# %%
data = {'date_col':[]}
with open('../data/telegram/yementodaychannl.csv', 'r') as infile:
    infile.readline()
    for line in infile:
        parts = line.strip().split(',')
        data['date_col'].append(parts[1]+' '+parts[2])
        
df = pd.DataFrame(data)
df.date_col = pd.to_datetime(df.date_col)
df = df.date_col.value_counts().reset_index()
df.columns = ['date_col', 'count_col']
df = df.sort_values('date_col')

# %%
df.date_col.hist()

# %%
per_day_df = df.set_index('date_col').groupby(pd.TimeGrouper('1D')).sum().fillna(0).reset_index()
per_day_df.plot(x='date_col', y='count_col', kind='line')

# %% [markdown]
# ---

# %%
results = capyldi(df, ['arima', 'mmpp', 'bcp', 'twitter_breakout'])
# Out:
# Getting time crosstabs:   0%|          | 0/9 [00:00<?, ?it/s]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:07<00:00,  7.07s/it]
# Getting time crosstabs:  11%|█         | 1/9 [00:07<00:56,  7.08s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:03<00:00,  3.93s/it]
# Getting time crosstabs:  22%|██▏       | 2/9 [00:11<00:42,  6.14s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it]
# Getting time crosstabs:  33%|███▎      | 3/9 [00:15<00:33,  5.66s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:06<00:00,  6.68s/it]
# Getting time crosstabs:  44%|████▍     | 4/9 [00:22<00:29,  5.97s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# Getting time crosstabs:  56%|█████▌    | 5/9 [00:24<00:19,  4.84s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:02<00:00,  2.83s/it]
# Getting time crosstabs:  67%|██████▋   | 6/9 [00:27<00:12,  4.24s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Getting time crosstabs: 100%|██████████| 9/9 [00:27<00:00,  3.04s/it]
# Grouping by time interval:   0%|          | 0/11 [00:00<?, ?it/s]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:04<00:09,  4.71s/it]
# Analyzing:  67%|██████▋   | 2/3 [00:08<00:04,  4.42s/it]
# Analyzing: 100%|██████████| 3/3 [00:11<00:00,  4.02s/it]
# Grouping by time interval:   9%|▉         | 1/11 [00:11<01:55, 11.55s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:02<00:04,  2.48s/it]
# Analyzing:  67%|██████▋   | 2/3 [00:04<00:02,  2.34s/it]
# Analyzing: 100%|██████████| 3/3 [00:05<00:00,  2.03s/it]
# Grouping by time interval:  18%|█▊        | 2/11 [00:17<01:28,  9.83s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.08it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.07it/s]
# Analyzing: 100%|██████████| 3/3 [00:02<00:00,  1.24it/s]
# Grouping by time interval:  27%|██▋       | 3/11 [00:19<01:00,  7.60s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.20it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.23it/s]
# Analyzing: 100%|██████████| 3/3 [00:02<00:00,  1.39it/s]
# Grouping by time interval:  36%|███▋      | 4/11 [00:21<00:41,  5.95s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.27it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.29it/s]
# Analyzing: 100%|██████████| 3/3 [00:02<00:00,  1.45it/s]
# Grouping by time interval:  45%|████▌     | 5/11 [00:23<00:28,  4.78s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.36it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.34it/s]
# Analyzing: 100%|██████████| 3/3 [00:01<00:00,  1.49it/s]
# Grouping by time interval:  55%|█████▍    | 6/11 [00:25<00:19,  3.95s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.39it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.36it/s]
# Analyzing: 100%|██████████| 3/3 [00:02<00:00,  1.50it/s]
# Grouping by time interval:  64%|██████▎   | 7/11 [00:27<00:13,  3.37s/it]

# %%
import pickle
with open('results_yementodaychannl.pkl', 'wb') as outfile:
    pickle.dump(results, outfile)
