# %% [markdown]
# In this notebook, we play around with using Capyldi (Capaldi?) to do bulk runs on the whereistheboom.csv dump.

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
import numpy.random as npr
from tqdm import tqdm
import requests
import sys

sys.path.append('../../../capyldi')
from capyldi import capyldi

# %matplotlib inline

# %%
df = pd.read_table('../data/twitter_from_matt/yemen_historic_tweets_timeseries.csv',
                   sep=';',
                   parse_dates=['posted_time'])
df = df.posted_time.value_counts().reset_index()
df.columns =['date_col', 'count_col']

# %%
df.date_col.hist()

# %%
per_day_df = df.set_index('date_col').groupby(pd.TimeGrouper('1D')).sum().fillna(0).reset_index()
per_day_df.plot(x='date_col', y='count_col', kind='line')

# %% [markdown]
# ---

# %%
results = capyldi(df)
# Out:
# Getting time crosstabs:   0%|          | 0/9 [00:00<?, ?it/s]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:36<00:00, 36.75s/it]
# Getting time crosstabs:  11%|█         | 1/9 [00:36<04:54, 36.79s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:33<00:00, 33.25s/it]
# Getting time crosstabs:  22%|██▏       | 2/9 [01:10<04:10, 35.74s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:33<00:00, 33.07s/it]
# Getting time crosstabs:  33%|███▎      | 3/9 [01:43<03:29, 34.95s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:37<00:00, 37.31s/it]
# Getting time crosstabs:  44%|████▍     | 4/9 [02:20<02:58, 35.67s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:26<00:00, 26.20s/it]
# Getting time crosstabs:  56%|█████▌    | 5/9 [02:46<02:11, 32.84s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Analyzing: 100%|██████████| 1/1 [00:27<00:00, 27.56s/it]
# Getting time crosstabs:  67%|██████▋   | 6/9 [03:14<01:33, 31.26s/it]
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Analyzing:   0%|          | 0/1 [00:00<?, ?it/s]
# Getting time crosstabs: 100%|██████████| 9/9 [03:14<00:00, 21.60s/it]
# Grouping by time interval:   0%|          | 0/11 [00:00<?, ?it/s]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:24<00:48, 24.13s/it]
# Analyzing:  67%|██████▋   | 2/3 [00:46<00:23, 23.49s/it]
# Analyzing: 100%|██████████| 3/3 [01:11<00:00, 24.12s/it]
# Grouping by time interval:   9%|▉         | 1/11 [01:11<11:57, 71.75s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:08<00:16,  8.31s/it]
# Analyzing:  67%|██████▋   | 2/3 [00:21<00:09,  9.67s/it]
# Analyzing: 100%|██████████| 3/3 [00:29<00:00,  9.19s/it]
# Grouping by time interval:  18%|█▊        | 2/11 [01:41<08:51, 59.00s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:01<00:03,  1.64s/it]
# Analyzing:  67%|██████▋   | 2/3 [00:03<00:01,  1.63s/it]
# Analyzing: 100%|██████████| 3/3 [00:03<00:00,  1.34s/it]
# Grouping by time interval:  27%|██▋       | 3/11 [01:44<05:39, 42.48s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:01<00:02,  1.21s/it]
# Analyzing:  67%|██████▋   | 2/3 [00:02<00:01,  1.19s/it]
# Analyzing: 100%|██████████| 3/3 [00:02<00:00,  1.00it/s]
# Grouping by time interval:  36%|███▋      | 4/11 [01:47<03:34, 30.61s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.15it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.19it/s]
# Analyzing: 100%|██████████| 3/3 [00:02<00:00,  1.31it/s]
# Grouping by time interval:  45%|████▌     | 5/11 [01:50<02:12, 22.10s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.37it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.37it/s]
# Analyzing: 100%|██████████| 3/3 [00:01<00:00,  1.53it/s]
# Grouping by time interval:  55%|█████▍    | 6/11 [01:52<01:20, 16.06s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.40it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.40it/s]
# Analyzing: 100%|██████████| 3/3 [00:01<00:00,  1.55it/s]
# Grouping by time interval:  64%|██████▎   | 7/11 [01:54<00:47, 11.83s/it]
# Analyzing:   0%|          | 0/3 [00:00<?, ?it/s]
# Analyzing:  33%|███▎      | 1/3 [00:00<00:01,  1.42it/s]
# Analyzing:  67%|██████▋   | 2/3 [00:01<00:00,  1.42it/s]
# Analyzing: 100%|██████████| 3/3 [00:01<00:00,  1.56it/s]
# Grouping by time interval: 100%|██████████| 11/11 [01:55<00:00, 10.54s/it]

# %%
import pickle
with open('results_yemen_historic_tweets.pkl', 'wb') as outfile:
    pickle.dump(results, outfile)
